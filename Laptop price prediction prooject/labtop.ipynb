# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("laptop_data.csv")
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Ram'] = df['Ram'].astype('int64')
df['Weight'] =df['Weight'].astype('float64')

# %% [markdown]
# ## **EDA**
#
# 1. Univariate Analyis
#
#  Check the Price distribution

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
# Create a distribution plot using seaborn
sns.displot(df['Price'])

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 5))
# count the number of labtop of each company
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(10, 5))
# Create a bar plot using seaborn with the sorted DataFrame
sns.barplot(x=df['Company'], y=df['Price'], data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# check the types of labtop
plt.figure(figsize=(10, 5)) 
df['TypeName'].value_counts().plot(kind='bar',color='green')
plt.xticks(rotation=0)
plt.show()

# %%
## Which type of labtop are Costly 
plt.figure(figsize=(10, 5))
# Create a bar plot using seaborn with the sorted DataFrame
sns.barplot(x=df['TypeName'], y=df['Price'], data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# which size are most used 
sns.distplot(df['Inches'])
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\1294059583.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])

# %%
plt.figure(figsize=(10, 5))
df['Inches'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.scatterplot(x = df['Inches'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Inches', ylabel='Price'>

# %%
plt.figure(figsize=(10, 5))
df['ScreenResolution'].value_counts().plot(kind='bar')
plt.show()

# %%
df[df['ScreenResolution'].str.contains('Touchscreen')]
# Out:
#      Company            TypeName  Inches  \
# 19      Dell           Ultrabook    13.3
# 23      Dell  2 in 1 Convertible    13.3
# 33      Dell           Ultrabook    13.3
# 44      Dell  2 in 1 Convertible    17.3
# 50    Lenovo  2 in 1 Convertible    10.1
# ...      ...                 ...     ...
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1284  Lenovo  2 in 1 Convertible    14.0
# 1285  Lenovo  2 in 1 Convertible    13.3
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# 19     IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 23               Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# 33              Touchscreen / Quad HD+ 3200x1800   Intel Core i7 8550U 1.8GHz
# 44               Full HD / Touchscreen 1920x1080   Intel Core i5 8250U 1.6GHz
# ...

# %%
## Touchscreen column is created to count the the touch screen labtop and find out the price diffenece b/w touchscreen and Non 
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0 )

# %%
# this show 200 labtop having touch screen function
df['Touchscreen'].value_counts().plot(kind='bar',color = 'pink')
# Out:
# <AxesSubplot: >

# %%
# now check the price differnce b/w Touchscreen and non Touch screen
sns.barplot(x= df['Touchscreen'],y= df['Price'],data= df)
# Out:
# <AxesSubplot: xlabel='Touchscreen', ylabel='Price'>

# %%
# check ScreenResolution columns having IPS or and you see in the dataframe below all IPS are show
df[df['ScreenResolution'].str.contains('IPS')]
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# 6      Apple           Ultrabook    15.4
# 9       Acer           Ultrabook    14.0
# ...      ...                 ...     ...
# 1285  Lenovo  2 in 1 Convertible    13.3
# 1289    Asus           Ultrabook    13.3
# 1293  Lenovo            Notebook    15.6
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
#
#                                 ScreenResolution                          Cpu  \
# 0             IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 3             IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz
# 4             IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz
# 6             IPS Panel Retina Display 2880x1800         Intel Core i7 2.2GHz
# ...

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
## IPS Price Comparison which one are costly
plt.figure(figsize=(10,6))
sns.barplot(x=df['IPS'],y = df['Price'],data= df)
plt.show()

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
## GET X_axis resolutions only not get the any string values
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0])

# %%
# Change datatype of X_res,y_res into int
df['X_res'] = df['X_res'].astype('int64')
df['Y_res'] = df['Y_res'].astype('int64')

# %%
# check the relation with Price
df.corr()['Price']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\313245557.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
# make a new column PPI by using these three columns X_res,y_res,Inches etc
df['PPI'] = (((df['X_res']**2)+(df['Y_res']**2))**0.5 /df['Inches'])

# %%
# we do feature engineering and make one column by using these three column so there is not need 
df.drop(columns={'ScreenResolution','Inches','X_res','Y_res'},inplace=True)

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu'].apply(lambda x:x.split()[0:3])
# Out:
# 0            [Intel, Core, i5]
# 1            [Intel, Core, i5]
# 2            [Intel, Core, i5]
# 3            [Intel, Core, i7]
# 4            [Intel, Core, i5]
#                  ...
# 1298         [Intel, Core, i7]
# 1299         [Intel, Core, i7]
# 1300    [Intel, Celeron, Dual]
# 1301         [Intel, Core, i7]
# 1302    [Intel, Celeron, Dual]
# Name: Cpu, Length: 1303, dtype: object

# %%
# remove , between  [Intel, Core, i5] and make a string by using " ",join
df['Cpu_Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
def processor_name(text):
    if text == 'Intel Core i3' or text == 'Intel Core i5' or text == 'Intel Core i7':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_brand'] = df['Cpu_Name'].apply(processor_name)

# %%
df.drop(columns = {'Cpu_Name','Cpu'},inplace=True)

# %%
df['Cpu_brand'].value_counts().plot(kind='bar',color='skyblue')
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(7, 5))
sns.barplot(x=df['Cpu_brand'],y = df['Price'],data= df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#   **RAM  Anaysis**

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(7, 5))
sns.barplot(x=df['Ram'],y = df['Price'],data= df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Memory Analysis**

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0','',regex= True)
df['Memory'] = df['Memory'].str.replace('GB','')
df['Memory'] = df['Memory'].str.replace('TB','000')
new = df['Memory'].str.split('+',n=1,expand =True)

df['first'] = new[0]
df['first']=df['first'].str.strip()

df['second']= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')
df['second'].fillna('0',inplace=True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df['first']=df['first'].astype('int64')
df['second']=df['second'].astype('int64')

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns={'first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'},inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\557439061.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\557439061.py:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head(1)
# Out:
#   Company   TypeName  Ram   Memory                           Gpu  OpSys  \
# 0   Apple  Ultrabook    8  128 SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight       Price  Touchscreen  IPS         PPI      Cpu_brand  HDD  SSD  \
# 0    1.37  71378.6832            0    1  226.983005  Intel Core i5    0  128
#
#    Hybrid  Flash_Storage
# 0       0              0

# %%
df.corr()['Price']
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\815546952.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns ={'Hybrid','Flash_Storage','Memory'},inplace =True)

# %% [markdown]
# **Gpu Column Analysis**

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
#Extract the first values of this column
df['Gpu brand'] = df['Gpu'].apply(lambda x: x.split()[0])
df['Gpu brand']
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3         AMD
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301      AMD
# 1302    Intel
# Name: Gpu brand, Length: 1303, dtype: object

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df =  df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
## Price Analysis with Gpu brand
plt.figure(figsize=(7, 5))
sns.barplot(x=df['Gpu brand'],y = df['Price'],data= df)
plt.xticks(rotation=45)
plt.show()

# %%
df.drop(columns='Gpu',inplace=True)

# %% [markdown]
# **OpSys Analysis**

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
def operating_sys(inp):
    if inp == "Windows 10" or inp == "Windows 7" or inp == "Windows 10 S":
        return "Windows"
    elif inp == 'macOS' or inp == 'Mac OS X':
        return "Apple/Mac"
    else:
        return 'Others/OS/Linux'

# %%
df['os'] = df['OpSys'].apply(operating_sys)

# %%
df.drop(columns='OpSys',inplace=True)

# %%
## Price Analysis with operating_system
plt.figure(figsize=(7, 5))
sns.barplot(x=df['os'],y = df['Price'],data= df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Weight**

# %%
sns.distplot(df['Weight'])
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\2601973532.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <AxesSubplot: xlabel='Weight', ylabel='Price'>

# %%
# Assuming you have your DataFrame 'df' and want to plot its correlation heatmap
corr_matrix = df.corr()

# Set up the figure size
plt.figure(figsize=(7, 5))

# Create the heatmap with annotations
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)

# Add a title
plt.title('Correlation Heatmap')

# Display the plot
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\589971981.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_5952\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns='Price')
y = np.log(df['Price'])

# %%
X.head()
# Out:
#   Company   TypeName  Ram  Weight  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34            0    0  127.677940
# 2      HP   Notebook    8    1.86            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu brand               os
# 0  Intel Core i5    0  128     Intel        Apple/Mac
# 1  Intel Core i5    0    0     Intel        Apple/Mac
# 2  Intel Core i5    0  256     Intel  Others/OS/Linux
# 3  Intel Core i7    0  512       AMD        Apple/Mac
# 4  Intel Core i5    0  256     Intel        Apple/Mac

# %%
y.head()
# Out:
# 0    11.175755
# 1    10.776777
# 2    10.329931
# 3    11.814476
# 4    11.473101
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
ColumnTransformer(Transformer=[('one_enc',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])],remainder='passthrough')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\GitHub\100_days_ML\CampusX-ML\Laptop price prediction prooject\labtop.ipynb Cell 77 in 1
# ----> <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/CampusX-ML/Laptop%20price%20prediction%20prooject/labtop.ipynb#Y126sZmlsZQ%3D%3D?line=0'>1</a> ColumnTransformer(Transformer=[('one_enc',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])],remainder='passthrough')
#
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'Transformer'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int64
#  3   Weight       1302 non-null   float64
#  4   Price        1302 non-null   float64
#  5   Touchscreen  1302 non-null   int64
#  6   IPS          1302 non-null   int64
#  7   PPI          1302 non-null   float64
#  8   Cpu_brand    1302 non-null   object
#  9   HDD          1302 non-null   int64
#  10  SSD          1302 non-null   int64
#  11  Gpu brand    1302 non-null   object
#  12  os           1302 non-null   object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 142.4+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu brand               os
# 0  Intel Core i5    0  128     Intel        Apple/Mac
# 1  Intel Core i5    0    0     Intel        Apple/Mac
# 2  Intel Core i5    0  256     Intel  Others/OS/Linux
# 3  Intel Core i7    0  512       AMD        Apple/Mac
# 4  Intel Core i5    0  256     Intel        Apple/Mac
