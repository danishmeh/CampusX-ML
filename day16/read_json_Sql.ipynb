# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1.Woking with JSON

# %%
pd.read_json("test.json").info()
df = pd.read_json("test.json",dtype={'id':float})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9944 entries, 0 to 9943
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9944 non-null   int64
#  1   ingredients  9944 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 155.5+ KB

# %%
df = pd.read_json("test.json",dtype={'id':float})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9944 entries, 0 to 9943
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9944 non-null   float64
#  1   ingredients  9944 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 155.5+ KB

# %%
dfs = pd.read_json("train.json",lines=True,chunksize=50)

# %% [markdown]
# 2. Read API json format URL link

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR").head(3)
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  INR 2023-07-24
# AFN  https://www.exchangerate-api.com/terms  INR 2023-07-24
# ALL  https://www.exchangerate-api.com/terms  INR 2023-07-24
#
#      time_last_updated   rates
# AED         1690156801  0.0448
# AFN         1690156801  1.0500
# ALL         1690156801  1.1100

# %% [markdown]
# 3.Working with SQL
#
# !pip install mysql.connector

# %%
import mysql.connector
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query("SELECT * FROM CITY",conn)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\1505015275.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY",conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode like 'USA'",conn)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\861600918.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode like 'USA'",conn)
#        ID          Name CountryCode        District  Population
# 0    3793      New York         USA        New York     8008278
# 1    3794   Los Angeles         USA      California     3694820
# 2    3795       Chicago         USA        Illinois     2896016
# 3    3796       Houston         USA           Texas     1953631
# 4    3797  Philadelphia         USA    Pennsylvania     1517550
# ..    ...           ...         ...             ...         ...
# 269  4062       Kenosha         USA       Wisconsin       89447
# 270  4063         Elgin         USA        Illinois       89408
# ...

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode like 'PAK'",conn).head()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\3050535178.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode like 'PAK'",conn).head()
#      ID        Name CountryCode District  Population
# 0  2822     Karachi         PAK    Sindh     9269265
# 1  2823      Lahore         PAK   Punjab     5063499
# 2  2824  Faisalabad         PAK   Punjab     1977246
# 3  2825  Rawalpindi         PAK   Punjab     1406214
# 4  2826      Multan         PAK   Punjab     1182441

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE District like 'punjab'",conn).head()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\3480124929.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE District like 'punjab'",conn).head()
#      ID                   Name CountryCode District  Population
# 0  1039               Ludhiana         IND   Punjab     1042740
# 1  1054               Amritsar         IND   Punjab      708835
# 2  1071  Jalandhar (Jullundur)         IND   Punjab      509510
# 3  1129                Patiala         IND   Punjab      238368
# 4  1192    Bhatinda (Bathinda)         IND   Punjab      159042

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE District like 'sind'",conn)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\4039935213.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE District like 'sind'",conn)
#      ID         Name CountryCode District  Population
# 0  2847  Mirpur Khas         PAK     Sind      184500
# 1  2848    Nawabshah         PAK     Sind      183100
# 2  2855    Jacobabad         PAK     Sind      137700
# 3  2856    Shikarpur         PAK     Sind      133300
# 4  2867   Tando Adam         PAK     Sind      103400
# 5  2869     Khairpur         PAK     Sind      102200
# 6  2872         Dadu         PAK     Sind       98600

# %%
pd.read_sql_query("SELECT * FROM COUNTRY ",conn)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\3524242862.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM COUNTRY ",conn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %%
pd.read_sql_query("SELECT * FROM COUNTRY WHERE LifeExpectancy > 80 ",conn)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\1869357440.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM COUNTRY WHERE LifeExpectancy > 80 ",conn)
#   Code        Name Continent           Region  SurfaceArea  IndepYear  \
# 0  AND     Andorra    Europe  Southern Europe        468.0     1278.0
# 1  JPN       Japan      Asia     Eastern Asia     377829.0     -660.0
# 2  MAC       Macao      Asia     Eastern Asia         18.0        NaN
# 3  SGP   Singapore      Asia   Southeast Asia        618.0     1965.0
# 4  SMR  San Marino    Europe  Southern Europe         61.0      885.0
#
#    Population  LifeExpectancy        GNP     GNPOld  \
# 0       78000            83.5     1630.0        NaN
# 1   126714000            80.7  3787042.0  4192638.0
# ...

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
df.head()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7732\3942989376.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
#   CountryCode    Language IsOfficial  Percentage
# 0         ABW       Dutch          T         5.3
# 1         ABW     English          F         9.5
# 2         ABW  Papiamento          F        76.7
# 3         ABW     Spanish          F         7.4
# 4         AFG     Balochi          F         0.9

# %%
df.shape
# Out:
# (984, 4)

# %%
int(2+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\GitHub\100_days_ML\day16\read_json_Sql.ipynb Cell 20 in 1
# ----> <a href='vscode-notebook-cell:/e%3A/GitHub/100_days_ML/day16/read_json_Sql.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> int(2+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'
