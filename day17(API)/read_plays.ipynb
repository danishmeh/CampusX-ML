# %%
import pandas as pd
import requests

# %%
#809f378f7f805f9e86bbf92f7a9c30d5

# %%
##copy the API from TMBD website ,and paste in url after?paste API key with api_key
response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=809f378f7f805f9e86bbf92f7a9c30d5')

# %% [markdown]
# How to see the Json data in web
#
# 1.paste this link in the web browser
#
# https://api.themoviedb.org/3/movie/popular?api_key=809f378f7f805f9e86bbf92f7a9c30d5
# and copy the json data
#
# open  https://jsonviewer.stack.hu/  and paste the data you copy from above link
# here you view the the data

# %% [markdown]
# How to read Json format data

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/2vFuG6bWGyQUzYS9d69E5l85nIz.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 667538,
#    'original_language': 'en',
#    'original_title': 'Transformers: Rise of the Beasts',
#    'overview': 'When a new threat capable of destroying the entire planet emerges, Optimus Prime and the Autobots must team up with a powerful faction known as the Maximals. With the fate of humanity hanging in the balance, humans Noah and Elena will do whatever it takes to help the Transformers as they engage in the ultimate battle to save Earth.',
#    'popularity': 9226.916,
#    'poster_path': '/gPbM0MK8CP8A174rmUwGsADNYKD.jpg',
#    'release_date': '2023-06-06',
#    'title': 'Transformers: Rise of the Beasts',
#    'video': False,
#    'vote_average': 7.4,
#    'vote_count': 1766},
#   {'adult': False,
#    'backdrop_path': '/yF1eOkaYvwiORauRCPWznV9xVvi.jpg',
#    'genre_ids': [28, 12, 878],
#    'id': 298618,
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','original_title','release_date','vote_average']]

# %%
df.head()
# Out:
#         id                    original_title release_date  vote_average
# 0   667538  Transformers: Rise of the Beasts   2023-06-06           7.4
# 1   298618                         The Flash   2023-06-13           6.9
# 2   346698                            Barbie   2023-07-19           7.7
# 3   447365    Guardians of the Galaxy Vol. 3   2023-05-03           8.1
# 4  1076487                      Warhorse One   2023-06-30           6.8

# %%
# you see only only 20 row are show  but there is more then 39234 pages so how we get rest of by using loop
df.shape
# Out:
# (20, 4)

# %%
df = pd.DataFrame()
# down the code only 500 pages data are collected

# %%
for i in range(1,500):
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=809f378f7f805f9e86bbf92f7a9c30d5&page={}'.format(i))
    df_t = pd.DataFrame(response.json()['results'])[['id','original_title','release_date','vote_average']]
    df = df.append(df_t,ignore_index=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_2328\1135640898.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_t,ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_2328\1135640898.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_t,ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_2328\1135640898.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_t,ignore_index=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_2328\1135640898.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_t,ignore_index=True)
# ...

# %%
df.shape
# Out:
# (9980, 4)
